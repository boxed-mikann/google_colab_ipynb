# %% [markdown]
# <a href="https://colab.research.google.com/github/boxed-mikann/google_colab_ipynb/blob/main/BPEexercisesA2025_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **生物工学演習A後半　第３回**
#
# このページは生物工学演習A後半の授業資料です。閲覧・共有は受講者限りとします。

# %% [markdown]
# ## **チュートリアル・準備**
#
# カメラで動画を撮影して動画ファイルをColabサーバにアップロードするまで
#
# - 以下は例であり、他の手段を用いても構いません。
# - カメラが使えない場合、USB接続カメラを貸し出します（台数制限あり）。

# %% [markdown]
# <br>
#
# ### **1. 動画を撮影し、PCにファイルとして保存する**
#
# -  Windows PC付属のカメラを利用する場合： 「カメラ」アプリで動画を撮影し、ファイルとして保存する
# -  Mac付属のカメラを利用する場合：　「QuickTime Player」から「ファイル」ー「新規ムービー収録」で動画を撮影し、ファイルとして保存する
# -  スマートフォン等に付属のカメラを利用する場合：　スマートフォンで動画を撮影し、ケーブルもしくはAirDrop、Slack、Line等を介して動画ファイルをPCに転送する

# %% [markdown]
# <br>
#
# ### **2. Colabサーバに動画ファイルをアップロードする**
#
# (1) Colab画面左部のフォルダアイコンを押してColabサーバにあるファイルを表示する
#
# (2) 以下のいずれかでPCにあるファイルをColabサーバにアップロードする
#   - (a)  「セッションストレージにアップロード」ボタンを押してファイルを選択する
#   - (b) ファイル名の下の空白部分に動画ファイルをドラッグ＆ドロップする
#
# (3) ファイルが100%アップロードされるまで待つ（注：ファイルサイズや通信環境によっては数十秒〜数分かかる場合があります）
#
# <img src="https://nishimotolab.org/images/seeds/colab_folder_labels.png" width=50%>
#
# <br><br>

# %% [markdown]
# ---
#
# ## **2. 演習課題**
#
#
# **ここから演習課題です。以下の指示に従って課題に取り組み、解答を提出してください。**
#
# - 上記のチュートリアルや課題中の記述、またオンライン資料・参考書などを参照しながら演習を進めてください。
# - 解答にPythonを利用した場合、利用したコードとその結果を解答に含めてください。
# - 1日分の演習に対する解答を1ファイルにまとめ、WordあるいはPDF形式でCLEから提出してください。
# - 課題番号と解答の対応が判るように整理した解答を提出してください。
# - pynb（課題番号、コード、結果、テキスト解答が整理・明示されているもの）をPDFに変換して提出しても構いません。（Macの場合は「ファイル」→「プリント」→「PDF」）
# - 解答の提出は演習時間内を想定していますが、間に合わなければ所定の期限までに提出してください。
# - なお「オプション」となっている項目は応用問題です。難しければ必ずしも解答する必要はありませんが、解答は加点対象になります。
#
# <br>

# %% [markdown]
# ---
#
# ### **課題　rPPGで心拍計測を行う**
#
# rPPG（remote photoplethysmography)とは、皮膚の微細な血流変化に由来する信号を光学記録（動画等）から読み取ることで心拍等を計測する技術の一つです (*1)。一般的なカメラ等で計測が可能であり、感情や認知状態の推定、運動強度や睡眠状態のモニタリング、生体認証など、様々な応用が期待されています。
#
# <br>
#
# rPPGを行うためには生体の皮膚を一定時間撮影した動画が必要になります。以下のいずれかを利用して課題に取り組んでください。
#
# (A) （推奨）顔などの皮膚部分を含む15秒程度の動画を撮影する。
#
# (B) （上記が難しければ）以下のサンプル動画( *2)を利用する。
#
# <br>
#
# 1.  **上記の動画（AもしくはB）について、(1)皮膚部分にROI( *3)を設定、(2)ROI内の平均輝度の時系列をプロット、(3)時系列にバンドパスフィルタ（0.2-6Hz）を適用した上で周波数スペクトラムをプロット、を行ってください。また、ネガティブコントロール( *4)としてROIを同じ動画内の背景（人物以外の部分、壁等）に設定して上記と同様の解析を行ってください。これらにより、皮膚部位から心拍由来と考えられる信号成分（一般的には1-2Hz（60-120bpm）程度に現れるピーク）が計測できていることを確認してください。**
#
# 2.  （オプション）**運動直後などの心拍の変化が起きると推定される状態における動画撮影（~30秒程度）を行い、スペクトログラムをプロットすることで心拍数の時間変化が観察できるか確認してください。**
#
# <br>
#
# -  **（1-2で心拍と考えられる信号が全く見られなかった場合）信号が取れていないことを表すプロットを示した上で、なぜ今回の計測では信号が見られなかったのか、考えられる理由について考察してください。**
#
# <br>
#
# 参考: rPPG信号がうまく計測できない場合の工夫例
#   - 撮影中は被写体ができるだけ静止できるようにする
#   - ROIの位置と大きさを再検討する
#   - 照明や画角などの撮影条件を再検討する
#   - 手などの顔以外の皮膚部位を試す
#   - 撮影の時間・空間解像度などが適切かを確かめる
#   - 撮影に追加のフィルタ処理（美肌処理等）がかかっていないかを確かめる
#
#
#
# <br>
#
# *1 Verkruysse et al., 2008 Optics Express [link](https://doi.org/10.1364%2Foe.16.021434)
#
# *2 サンプル動画（リンク先右上の下矢印（ダウンロード）ボタンでダウンロード可能） https://www.dropbox.com/scl/fi/krox5w5spee1294yujz2v/test_0626.mov?rlkey=aar4l8hgybz1z9ezkluesvaq5&dl=0
#
#
# *3 ROI: region-of-interest　解析対象とする部位
#
# *4 効果を検証したい対象と同じ条件で、結果が陰性になると判っている対象に実験操作を行うこと。陰性対照実験。
#
# <br>
#
# ヒント：　以下のサンプルコードを参考にしても構いません。ただし、その場合は各行が何をしているかを理解しながら利用してください。

# %%
### mp4以外の形式の動画をアップロードした場合： 動画ファイル（例ではtest_0626.mov）をmp4形式に変換

# !ffmpeg -i test_0626.mov -loglevel error -vcodec libx264 -acodec aac output.mp4

# 注1: 動画ファイルがすでにx264形式のmp4ファイルの場合はこの変換処理は省略できます
# 注2: ファイルの大きさや動画の長さによっては数十秒〜数分かかる可能性があります

# %%
### 動画が正しく読み込めることを確認し、ROIを設定する

import cv2
import matplotlib.pyplot as plt
import numpy as np

# 動画ファイルの読み込み
video_path = '/content/output.mp4'
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print(f'ファイル {video_path} が読み込めませんでした。')
else:
    print(f'ファイル {video_path} は正しく読み込まれました。')

if cap.isOpened():
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)

    print(f'総フレーム数: {total_frames}')
    print(f'幅: {width}')
    print(f'高さ: {height}')
    print(f'FPS: {fps}') # frames per second

# 矩形ROIの指定（左上の(x1, y1)と右下の(x2, y2)）
x1, y1, x2, y2 = 900, 700, 1000, 800

# スナップショットの表示
cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
ret, frame = cap.read()
if ret:
    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
    plt.figure(figsize=(8, 8))
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.title('Snapshot with ROI')

plt.show()
cap.release()

# %%
### 動画フレームを読んでROI内の平均輝度を計算し、時系列をプロットする

cap = cv2.VideoCapture(video_path)

# 輝度平均を格納するリストを用意
luminance_means = []

# 動画をフレームごとに処理
while True:
    ret, frame = cap.read()
    if not ret:
        break

    # 矩形領域の抽出
    roi = frame[y1:y2, x1:x2]

    # 輝度（グレースケール）に変換し、平均を計算
    gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    luminance_mean = np.mean(gray)
    luminance_means.append(luminance_mean)
cap.release()

# 平均輝度の時系列をプロット
plt.figure(figsize=(10, 5))
plt.plot(luminance_means)
plt.title('Luminance Average Over Time')
plt.xlabel('Frame')
plt.ylabel('Average Luminance')
plt.show()

# %%
### 時系列信号にバンドパスフィルタを適用し、心拍由来と考えられる信号（通常は1-2Hz程度のピーク）が見られるか確認する

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, filtfilt
from numpy.fft import fft, fftfreq

# バターワース・バンドパスフィルタの設定
nyquist_freq = 0.5 * fps
low_cutoff = 0.2  # バンドパスフィルタの下限周波数
high_cutoff = 6  # バンドパスフィルタの上限周波数
order = 5  # フィルタの次数

# フィルタ係数の計算
b, a = butter(order, [low_cutoff / nyquist_freq, high_cutoff / nyquist_freq], btype='band')

# フィルタの適用
filtered_luminance_means = filtfilt(b, a, luminance_means)

# フーリエ変換の実行
fft_data = fft(filtered_luminance_means)
amplitude_spectrum = np.abs(fft_data)

# 周波数軸の作成
dt = 1 / fps
N = len(filtered_luminance_means)
xf = fftfreq(N, dt)

# プロット
plt.figure(figsize=(10, 10))

plt.subplot(2, 1, 1)
plt.plot(filtered_luminance_means)
plt.title('Filtered Luminance Average Over Time')
plt.xlabel('Frame')
plt.ylabel('Average Luminance')

plt.subplot(2, 1, 2)
plt.plot(xf, amplitude_spectrum)
plt.title('Amplitude Spectrum')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude')
plt.xlim([0, 6])

plt.show()

# %%
### 短時間フーリエ変換を行い、スペクトログラムを表示する

import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import stft

# 時系列データ
time_series = filtered_luminance_means

# 短時間フーリエ変換の実行
f, t, Zxx = stft(time_series, fs=fps, nperseg=fps*8)

# プロット
plt.figure(figsize=(10, 5))
plt.pcolormesh(t, f, np.abs(Zxx), shading='gouraud')
plt.title('Spectrogram')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.ylim(0,6)
plt.show()
